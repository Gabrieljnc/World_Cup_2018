# %%
import requests
from pandas import json_normalize
from Modules import extract_matches


def normalizing(match_id):
        read_events = requests.get("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+str(match_id)+'.json')       
        events = read_events.json() 
        events_df = json_normalize(events, sep = '_')
        return events_df


class ExtractEvents:
    def matches_ids(self):
        self.extract_matches_df = extract_matches.ExtractMatches(43,3).matches_list()

        self.all_matches_ids = []
        for id in self.extract_matches_df['match_id']:
            self.all_matches_ids.append(id)

        return sorted(self.all_matches_ids)

    def event_7525(self):
        list_of_ids = self.matches_ids()

        if 7525 in list_of_ids:
            match_7525 = normalizing(7525)
            return match_7525
        else:
            print('Match not found')

    def event_7529(self):
        list_of_ids = self.matches_ids()

        if 7529 in list_of_ids:
            match_7529 = normalizing(7529)
            return match_7529
        else:
            print('Match not found')

    def event_7530(self):
        list_of_ids = self.matches_ids()

        if 7530 in list_of_ids:
            match_7530 = normalizing(7530)
            return match_7530
        else:
            print('Match not found')

    def event_7531(self):
        list_of_ids = self.matches_ids()

        if 7531 in list_of_ids:
            match_7531 = normalizing(7531)
            return match_7531
        else:
            print('Match not found')

    def event_7532(self):
        list_of_ids = self.matches_ids()

        if 7532 in list_of_ids:
            match_7532 = normalizing(7532)
            return match_7532
        else:
            print('Match not found')

    def event_7533(self):

        list_of_ids = self.matches_ids()

        if 7533 in list_of_ids:
            match_7533 = normalizing(7533)
            return match_7533
        else:
            print('Match not found')

    def event_7534(self):

        list_of_ids = self.matches_ids()

        if 7534 in list_of_ids:
            match_7534 = normalizing(7534)
            return match_7534
        else:
            print('Match not found')

    def event_7535(self):
        list_of_ids = self.matches_ids()

        if 7535 in list_of_ids:
            match_7535 = normalizing(7535)
            return match_7535
        else:
            print('Match not found')

    def event_7536(self):
        list_of_ids = self.matches_ids()

        if 7536 in list_of_ids:
            match_7536 = normalizing(7536)
            return match_7536
        else:
            print('Match not found')

    def event_7537(self):
        list_of_ids = self.matches_ids()

        if 7537 in list_of_ids:
            match_7537 = normalizing(7537)
            return match_7537
        else:
            print('Match not found')

    def event_7538(self):
        list_of_ids = self.matches_ids()

        if 7538 in list_of_ids:
            match_7538 = normalizing(7538)
            return match_7538
        else:
            print('Match not found')

    def event_7539(self):
        list_of_ids = self.matches_ids()

        if 7539 in list_of_ids:
            match_7539 = normalizing(7539)
            return match_7539
        else:
            print('Match not found')

    def event_7540(self):
        list_of_ids = self.matches_ids()

        if 7540 in list_of_ids:
            match_7540 = normalizing(7540)
            return match_7540
        else:
            print('Match not found')

    def event_7541(self):
        list_of_ids = self.matches_ids()

        if 7541 in list_of_ids:
            match_7541 = normalizing(7541)
            return match_7541
        else:
            print('Match not found')

    def event_7542(self):
        list_of_ids = self.matches_ids()

        if 7542 in list_of_ids:
            match_7542 = normalizing(7542)
            return match_7542
        else:
            print('Match not found')

    def event_7543(self):
        list_of_ids = self.matches_ids()

        if 7543 in list_of_ids:
            match_7543 = normalizing(7543)
            return match_7543
        else:
            print('Match not found')

    def event_7544(self):
        list_of_ids = self.matches_ids()

        if 7544 in list_of_ids:
            match_7544 = normalizing(7544)
            return match_7544
        else:
            print('Match not found')

    def event_7545(self):
        list_of_ids = self.matches_ids()

        if 7545 in list_of_ids:
            match_7545 = normalizing(7545)
            return match_7545
        else:
            print('Match not found')

    def event_7546(self):
        list_of_ids = self.matches_ids()

        if 7546 in list_of_ids:
            match_7546 = normalizing(7546)
            return match_7546
        else:
            print('Match not found')

    def event_7547(self):
        list_of_ids = self.matches_ids()

        if 7547 in list_of_ids:
            match_7547 = normalizing(7547)
            return match_7547
        else:
            print('Match not found')

    def event_7548(self):
        list_of_ids = self.matches_ids()

        if 7548 in list_of_ids:
            match_7548 = normalizing(7548)
            return match_7548
        else:
            print('Match not found')

    def event_7549(self):
        list_of_ids = self.matches_ids()

        if 7549 in list_of_ids:
            match_7549 = normalizing(7549)
            return match_7549
        else:
            print('Match not found')

    def event_7550(self):
        list_of_ids = self.matches_ids()

        if 7550 in list_of_ids:
            match_7550 = normalizing(7550)
            return match_7550
        else:
            print('Match not found')

    def event_7551(self):
        list_of_ids = self.matches_ids()

        if 7551 in list_of_ids:
            match_7551 = normalizing(7551)
            return match_7551
        else:
            print('Match not found')

    def event_7552(self):
        list_of_ids = self.matches_ids()

        if 7552 in list_of_ids:
            match_7552 = normalizing(7552)
            return match_7552
        else:
            print('Match not found')

    def event_7553(self):
        list_of_ids = self.matches_ids()

        if 7553 in list_of_ids:
            match_7553 = normalizing(7553)
            return match_7553
        else:
            print('Match not found')

    def event_7554(self):
        list_of_ids = self.matches_ids()

        if 7554 in list_of_ids:
            match_7554 = normalizing(7554)
            return match_7554
        else:
            print('Match not found')

    def event_7555(self):
        list_of_ids = self.matches_ids()

        if 7555 in list_of_ids:
            match_7555 = normalizing(7555)
            return match_7555
        else:
            print('Match not found')

    def event_7556(self):
        list_of_ids = self.matches_ids()

        if 7556 in list_of_ids:
            match_7556 = normalizing(7556)
            return match_7556
        else:
            print('Match not found')

    def event_7557(self):
        list_of_ids = self.matches_ids()

        if 7557 in list_of_ids:
            match_7557 = normalizing(7557)
            return match_7557
        else:
            print('Match not found')

    def event_7558(self):
        list_of_ids = self.matches_ids()

        if 7558 in list_of_ids:
            match_7558 = normalizing(7558)
            return match_7558
        else:
            print('Match not found')

    def event_7559(self):
        list_of_ids = self.matches_ids()

        if 7559 in list_of_ids:
            match_7559 = normalizing(7559)
            return match_7559
        else:
            print('Match not found')

    def event_7560(self):
        list_of_ids = self.matches_ids()

        if 7560 in list_of_ids:
            match_7560 = normalizing(7560)
            return match_7560
        else:
            print('Match not found')

    def event_7561(self):
        list_of_ids = self.matches_ids()

        if 7561 in list_of_ids:
            match_7561 = normalizing(7561)
            return match_7561
        else:
            print('Match not found')

    def event_7562(self):
        list_of_ids = self.matches_ids()

        if 7562 in list_of_ids:
            match_7562 = normalizing(7562)
            return match_7562
        else:
            print('Match not found')

    def event_7563(self):
        list_of_ids = self.matches_ids()

        if 7563 in list_of_ids:
            match_7563 = normalizing(7563)
            return match_7563
        else:
            print('Match not found')

    def event_7564(self):
        list_of_ids = self.matches_ids()

        if 7564 in list_of_ids:
            match_7564 = normalizing(7564)
            return match_7564
        else:
            print('Match not found')

    def event_7565(self):
        list_of_ids = self.matches_ids()

        if 7565 in list_of_ids:
            match_7565 = normalizing(7565)
            return match_7565
        else:
            print('Match not found')

    def event_7566(self):
        list_of_ids = self.matches_ids()

        if 7566 in list_of_ids:
            match_7566 = normalizing(7566)
            return match_7566
        else:
            print('Match not found')

    def event_7567(self):
        list_of_ids = self.matches_ids()

        if 7567 in list_of_ids:
            match_7567 = normalizing(7567)
            return match_7567
        else:
            print('Match not found')

    def event_7568(self):
        list_of_ids = self.matches_ids()

        if 7568 in list_of_ids:
            match_7568 = normalizing(7568)
            return match_7568
        else:
            print('Match not found')

    def event_7569(self):
        list_of_ids = self.matches_ids()

        if 7569 in list_of_ids:
            match_7569 = normalizing(7569)
            return match_7569
        else:
            print('Match not found')

    def event_7570(self):
        list_of_ids = self.matches_ids()

        if 7570 in list_of_ids:
            match_7570 = normalizing(7570)
            return match_7570
        else:
            print('Match not found')

    def event_7571(self):
        list_of_ids = self.matches_ids()

        if 7571 in list_of_ids:
            match_7571 = normalizing(7571)
            return match_7571
        else:
            print('Match not found')

    def event_7572(self):
        list_of_ids = self.matches_ids()

        if 7572 in list_of_ids:
            match_7572 = normalizing(7572)
            return match_7572
        else:
            print('Match not found')

    def event_7576(self):
        list_of_ids = self.matches_ids()

        if 7576 in list_of_ids:
            match_7576 = normalizing(7576)
            return match_7576
        else:
            print('Match not found')

    def event_7577(self):
        list_of_ids = self.matches_ids()

        if 7577 in list_of_ids:
            match_7577 = normalizing(7577)
            return match_7577
        else:
            print('Match not found')

    def event_7578(self):
        list_of_ids = self.matches_ids()

        if 7578 in list_of_ids:
            match_7578 = normalizing(7578)
            return match_7578
        else:
            print('Match not found')

    def event_7579(self):
        list_of_ids = self.matches_ids()

        if 7579 in list_of_ids:
            match_7579 = normalizing(7579)
            return match_7579
        else:
            print('Match not found')

    def event_7580(self):
        list_of_ids = self.matches_ids()

        if 7580 in list_of_ids:
            match_7580 = normalizing(7580)
            return match_7580
        else:
            print('Match not found')

    def event_7581(self):
        list_of_ids = self.matches_ids()

        if 7581 in list_of_ids:
            match_7581 = normalizing(7581)
            return match_7581
        else:
            print('Match not found')

    def event_7582(self):
        list_of_ids = self.matches_ids()

        if 7582 in list_of_ids:
            match_7582 = normalizing(7582)
            return match_7582
        else:
            print('Match not found')

    def event_7583(self):
        list_of_ids = self.matches_ids()

        if 7583 in list_of_ids:
            match_7583 = normalizing(7583)
            return match_7583
        else:
            print('Match not found')

    def event_7584(self):
        list_of_ids = self.matches_ids()

        if 7584 in list_of_ids:
            match_7584 = normalizing(7584)
            return match_7584
        else:
            print('Match not found')

    def event_7585(self):
        list_of_ids = self.matches_ids()

        if 7585 in list_of_ids:
            match_7585 = normalizing(7585)
            return match_7585
        else:
            print('Match not found')

    def event_7586(self):
        list_of_ids = self.matches_ids()

        if 7586 in list_of_ids:
            match_7586 = normalizing(7586)
            return match_7586
        else:
            print('Match not found')

    def event_8649(self):
        list_of_ids = self.matches_ids()

        if 8649 in list_of_ids:
            match_8649 = normalizing(8649)
            return match_8649
        else:
            print('Match not found')

    def event_8650(self):
        list_of_ids = self.matches_ids()

        if 8650 in list_of_ids:
            match_8650 = normalizing(8650)
            return match_8650
        else:
            print('Match not found')

    def event_8651(self):
        list_of_ids = self.matches_ids()

        if 8651 in list_of_ids:
            match_8651 = normalizing(8651)
            return match_8651
        else:
            print('Match not found')

    def event_8652(self):
        list_of_ids = self.matches_ids()

        if 8652 in list_of_ids:
            match_8652 = normalizing(8652)
            return match_8652
        else:
            print('Match not found')

    def event_8655(self):
        list_of_ids = self.matches_ids()

        if 8655 in list_of_ids:
            match_8655 = normalizing(8655)
            return match_8655
        else:
            print('Match not found')

    def event_8656(self):
        list_of_ids = self.matches_ids()

        if 8656 in list_of_ids:
            match_8656 = normalizing(8656)
            return match_8656
        else:
            print('Match not found')

    def event_8657(self):
        list_of_ids = self.matches_ids()

        if 8657 in list_of_ids:
            match_8657 = normalizing(8657)
            return match_8657
        else:
            print('Match not found')

    def event_8658(self):
        list_of_ids = self.matches_ids()

        if 8658 in list_of_ids:
            match_8658 = normalizing(8658)
            return match_8658
        else:
            print('Match not found')




match_7525 = ExtractEvents().event_7525()
match_7529 = ExtractEvents().event_7529()
match_7530 = ExtractEvents().event_7530()
match_7531 = ExtractEvents().event_7531()
match_7532 = ExtractEvents().event_7532()
match_7533 = ExtractEvents().event_7533()
match_7534 = ExtractEvents().event_7534()
match_7535 = ExtractEvents().event_7535()
match_7536 = ExtractEvents().event_7536()
match_7537 = ExtractEvents().event_7537()
match_7538 = ExtractEvents().event_7538()
match_7539 = ExtractEvents().event_7539()
match_7540 = ExtractEvents().event_7540()
match_7541 = ExtractEvents().event_7541()
match_7542 = ExtractEvents().event_7542()
match_7543 = ExtractEvents().event_7543()
match_7544 = ExtractEvents().event_7544()
match_7545 = ExtractEvents().event_7545()
match_7546 = ExtractEvents().event_7546()
match_7547 = ExtractEvents().event_7547()
match_7548 = ExtractEvents().event_7548()
match_7549 = ExtractEvents().event_7549()
match_7550 = ExtractEvents().event_7550()
match_7551 = ExtractEvents().event_7551()
match_7552 = ExtractEvents().event_7552()
match_7553 = ExtractEvents().event_7553()
match_7554 = ExtractEvents().event_7554()
match_7555 = ExtractEvents().event_7555()
match_7556 = ExtractEvents().event_7556()
match_7557 = ExtractEvents().event_7557()
match_7558 = ExtractEvents().event_7558()
match_7559 = ExtractEvents().event_7559()
match_7560 = ExtractEvents().event_7560()
match_7561 = ExtractEvents().event_7561()
match_7562 = ExtractEvents().event_7562()
match_7563 = ExtractEvents().event_7563()
match_7564 = ExtractEvents().event_7564()
match_7565 = ExtractEvents().event_7565()
match_7566 = ExtractEvents().event_7566()
match_7567 = ExtractEvents().event_7567()
match_7568 = ExtractEvents().event_7568()
match_7569 = ExtractEvents().event_7569()
match_7570 = ExtractEvents().event_7570()
match_7571 = ExtractEvents().event_7571()
match_7572 = ExtractEvents().event_7572()
match_7576 = ExtractEvents().event_7576()
match_7577 = ExtractEvents().event_7577()
match_7578 = ExtractEvents().event_7578()
match_7579 = ExtractEvents().event_7579()
match_7580 = ExtractEvents().event_7580()
match_7581 = ExtractEvents().event_7581()
match_7582 = ExtractEvents().event_7582()
match_7583 = ExtractEvents().event_7583()
match_7584 = ExtractEvents().event_7584()
match_7585 = ExtractEvents().event_7585()
match_7586 = ExtractEvents().event_7586()
match_8649 = ExtractEvents().event_8649()
match_8650 = ExtractEvents().event_8650()
match_8651 = ExtractEvents().event_8651()
match_8652 = ExtractEvents().event_8652()
match_8655 = ExtractEvents().event_8655()
match_8656 = ExtractEvents().event_8656()
match_8657 = ExtractEvents().event_8657()
match_8658 = ExtractEvents().event_8658()

# %%
dataframes = [match_8657,match_8658]

frame = {}

for key, value in enumerate(dataframes):# index(key) and value
    frame[key] = value # assigning data frame from list to key in dictionary

# %%
match_8655['related_events'].value_counts()
# Out:
# [8d3584d9-4955-4203-8aa3-f2dad98b9fe6]                                                                                3
# [06af6f22-a194-4d41-8b9a-5d7eae6c391d]                                                                                3
# [6ab6565c-b33d-4f7c-9750-37499892704a]                                                                                3
# [18b226c2-9b04-495b-a018-ed3d65cc9029]                                                                                3
# [80e596ae-f963-4fbb-b624-c6b646cb3106]                                                                                2
#                                                                                                                      ..
# [05355b36-3cfd-4c28-a4f2-850ed431ab8c, 234ab432-12b5-48a4-87e4-4fea41db49a5, 428994f0-1b10-44dc-9a59-db5edd908e40]    1
# [3ead8e74-79d1-4b3d-b9e0-9ea694bb0fac, 428994f0-1b10-44dc-9a59-db5edd908e40]                                          1
# [05355b36-3cfd-4c28-a4f2-850ed431ab8c, 56190ddd-ba96-4525-898e-1ab528d68745]                                          1
# [428994f0-1b10-44dc-9a59-db5edd908e40]                                                                                1
# [ef0fd15f-ed4b-48d0-b728-dcbfc7220452]                                                                                1
# Name: related_events, Length: 3121, dtype: int64

# %%
match_8657.drop(columns = {'tactics_lineup'})
# Out:
#                                         id  index  period     timestamp  \
# 0     04198d50-c681-4522-a809-683dea2e8f18      1       1  00:00:00.000
# 1     efe191f7-d38f-414d-8950-db48af1bd59b      2       1  00:00:00.000
# 2     0d585e73-42cc-49ec-902c-d1fed3551f95      3       1  00:00:00.000
# 3     75caf5e3-e038-4d52-b968-0df8bce24a8a      4       1  00:00:00.000
# 4     a7ec7898-799e-4e79-bc54-54d4cba812cf      5       1  00:00:00.533
# ...                                    ...    ...     ...           ...
# 4421  28e24160-4ef5-4131-a513-c416445beeaa   4422       2  00:47:46.631
# 4422  c22cda43-89cd-4c96-8fad-7d9195007bda   4423       2  00:47:46.631
# 4423  e69b56c4-7eca-4fbd-8ce5-a693477ad8bd   4424       2  00:48:02.538
# 4424  dba9a8bc-158b-4578-b98a-653145a3292f   4425       2  00:48:04.178
# 4425  11c762e6-8fb0-4342-98d4-f6505f99aa25   4426       2  00:48:04.178
#
#       minute  second  possession  duration  type_id       type_name  \
# 0          0       0           1     0.000       35     Starting XI
# 1          0       0           1     0.000       35     Starting XI
# 2          0       0           1       NaN       18      Half Start
# 3          0       0           1       NaN       18      Half Start
# 4          0       0           2     0.719       30            Pass
# ...      ...     ...         ...       ...      ...             ...
# 4421      92      46         151     0.000       22  Foul Committed
# 4422      92      46         151       NaN       21        Foul Won
# 4423      93       2         151     0.000       24   Bad Behaviour
# 4424      93       4         151       NaN       34        Half End
# 4425      93       4         151     0.000       34        Half End
#
#       possession_team_id possession_team_name  play_pattern_id  \
# 0                    782              Belgium                1
# 1                    782              Belgium                1
# 2                    782              Belgium                1
# 3                    782              Belgium                1
# 4                    782              Belgium                9
# ...                  ...                  ...              ...
# 4421                 782              Belgium                4
# 4422                 782              Belgium                4
# 4423                 782              Belgium                4
# 4424                 782              Belgium                4
# 4425                 782              Belgium                4
#
#      play_pattern_name  team_id team_name  tactics_formation  \
# 0         Regular Play      782   Belgium              343.0
# 1         Regular Play      768   England              352.0
# 2         Regular Play      768   England                NaN
# 3         Regular Play      782   Belgium                NaN
# 4        From Kick Off      782   Belgium                NaN
# ...                ...      ...       ...                ...
# 4421     From Throw In      782   Belgium                NaN
# 4422     From Throw In      768   England                NaN
# 4423     From Throw In      782   Belgium                NaN
# 4424     From Throw In      768   England                NaN
# 4425     From Throw In      782   Belgium                NaN
#
#                               related_events      location  player_id  \
# 0                                        NaN           NaN        NaN
# 1                                        NaN           NaN        NaN
# 2     [75caf5e3-e038-4d52-b968-0df8bce24a8a]           NaN        NaN
# 3     [0d585e73-42cc-49ec-902c-d1fed3551f95]           NaN        NaN
# 4     [842270b0-aad5-4088-a739-599d4c40ff66]  [61.0, 41.0]     3289.0
# ...                                      ...           ...        ...
# 4421  [c22cda43-89cd-4c96-8fad-7d9195007bda]  [64.0, 19.0]     6332.0
# 4422  [28e24160-4ef5-4131-a513-c416445beeaa]  [57.0, 62.0]    10955.0
# 4423                                     NaN           NaN     5642.0
# 4424  [11c762e6-8fb0-4342-98d4-f6505f99aa25]           NaN        NaN
# 4425  [dba9a8bc-158b-4578-b98a-653145a3292f]           NaN        NaN
#
#                player_name  position_id            position_name  \
# 0                      NaN          NaN                      NaN
# 1                      NaN          NaN                      NaN
# 2                      NaN          NaN                      NaN
# 3                      NaN          NaN                      NaN
# 4     Romelu Lukaku Menama         23.0           Center Forward
# ...                    ...          ...                      ...
# 4421      Thomas Vermaelen          5.0         Left Center Back
# 4422            Harry Kane         22.0     Right Center Forward
# 4423           Axel Witsel         11.0  Left Defensive Midfield
# 4424                   NaN          NaN                      NaN
# 4425                   NaN          NaN                      NaN
#
#       pass_recipient_id pass_recipient_name  pass_length  pass_angle  \
# 0                   NaN                 NaN          NaN         NaN
# 1                   NaN                 NaN          NaN         NaN
# 2                   NaN                 NaN          NaN         NaN
# 3                   NaN                 NaN          NaN         NaN
# 4                5642.0         Axel Witsel         10.0    3.141593
# ...                 ...                 ...          ...         ...
# 4421                NaN                 NaN          NaN         NaN
# 4422                NaN                 NaN          NaN         NaN
# 4423                NaN                 NaN          NaN         NaN
# 4424                NaN                 NaN          NaN         NaN
# 4425                NaN                 NaN          NaN         NaN
#
#       pass_height_id pass_height_name pass_end_location  pass_type_id  \
# 0                NaN              NaN               NaN           NaN
# 1                NaN              NaN               NaN           NaN
# 2                NaN              NaN               NaN           NaN
# 3                NaN              NaN               NaN           NaN
# 4                1.0      Ground Pass      [51.0, 41.0]          65.0
# ...              ...              ...               ...           ...
# 4421             NaN              NaN               NaN           NaN
# 4422             NaN              NaN               NaN           NaN
# 4423             NaN              NaN               NaN           NaN
# 4424             NaN              NaN               NaN           NaN
# 4425             NaN              NaN               NaN           NaN
#
#      pass_type_name  pass_body_part_id pass_body_part_name under_pressure  \
# 0               NaN                NaN                 NaN            NaN
# 1               NaN                NaN                 NaN            NaN
# 2               NaN                NaN                 NaN            NaN
# 3               NaN                NaN                 NaN            NaN
# 4          Kick Off               40.0          Right Foot            NaN
# ...             ...                ...                 ...            ...
# 4421            NaN                NaN                 NaN            NaN
# 4422            NaN                NaN                 NaN           True
# 4423            NaN                NaN                 NaN            NaN
# 4424            NaN                NaN                 NaN            NaN
# 4425            NaN                NaN                 NaN            NaN
#
#      carry_end_location  pass_outcome_id pass_outcome_name  \
# 0                   NaN              NaN               NaN
# 1                   NaN              NaN               NaN
# 2                   NaN              NaN               NaN
# 3                   NaN              NaN               NaN
# 4                   NaN              NaN               NaN
# ...                 ...              ...               ...
# 4421                NaN              NaN               NaN
# 4422                NaN              NaN               NaN
# 4423                NaN              NaN               NaN
# 4424                NaN              NaN               NaN
# 4425                NaN              NaN               NaN
#
#       ball_receipt_outcome_id ball_receipt_outcome_name  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ...                       ...                       ...
# 4421                      NaN                       NaN
# 4422                      NaN                       NaN
# 4423                      NaN                       NaN
# 4424                      NaN                       NaN
# 4425                      NaN                       NaN
#
#       interception_outcome_id interception_outcome_name counterpress  \
# 0                         NaN                       NaN          NaN
# 1                         NaN                       NaN          NaN
# 2                         NaN                       NaN          NaN
# 3                         NaN                       NaN          NaN
# 4                         NaN                       NaN          NaN
# ...                       ...                       ...          ...
# 4421                      NaN                       NaN          NaN
# 4422                      NaN                       NaN          NaN
# 4423                      NaN                       NaN          NaN
# 4424                      NaN                       NaN          NaN
# 4425                      NaN                       NaN          NaN
#
#       duel_outcome_id duel_outcome_name  duel_type_id duel_type_name  \
# 0                 NaN               NaN           NaN            NaN
# 1                 NaN               NaN           NaN            NaN
# 2                 NaN               NaN           NaN            NaN
# 3                 NaN               NaN           NaN            NaN
# 4                 NaN               NaN           NaN            NaN
# ...               ...               ...           ...            ...
# 4421              NaN               NaN           NaN            NaN
# 4422              NaN               NaN           NaN            NaN
# 4423              NaN               NaN           NaN            NaN
# 4424              NaN               NaN           NaN            NaN
# 4425              NaN               NaN           NaN            NaN
#
#       dribble_outcome_id dribble_outcome_name  50_50_outcome_id  \
# 0                    NaN                  NaN               NaN
# 1                    NaN                  NaN               NaN
# 2                    NaN                  NaN               NaN
# 3                    NaN                  NaN               NaN
# 4                    NaN                  NaN               NaN
# ...                  ...                  ...               ...
# 4421                 NaN                  NaN               NaN
# 4422                 NaN                  NaN               NaN
# 4423                 NaN                  NaN               NaN
# 4424                 NaN                  NaN               NaN
# 4425                 NaN                  NaN               NaN
#
#      50_50_outcome_name pass_cross pass_assisted_shot_id pass_goal_assist  \
# 0                   NaN        NaN                   NaN              NaN
# 1                   NaN        NaN                   NaN              NaN
# 2                   NaN        NaN                   NaN              NaN
# 3                   NaN        NaN                   NaN              NaN
# 4                   NaN        NaN                   NaN              NaN
# ...                 ...        ...                   ...              ...
# 4421                NaN        NaN                   NaN              NaN
# 4422                NaN        NaN                   NaN              NaN
# 4423                NaN        NaN                   NaN              NaN
# 4424                NaN        NaN                   NaN              NaN
# 4425                NaN        NaN                   NaN              NaN
#
#       shot_statsbomb_xg shot_end_location shot_key_pass_id  shot_outcome_id  \
# 0                   NaN               NaN              NaN              NaN
# 1                   NaN               NaN              NaN              NaN
# 2                   NaN               NaN              NaN              NaN
# 3                   NaN               NaN              NaN              NaN
# 4                   NaN               NaN              NaN              NaN
# ...                 ...               ...              ...              ...
# 4421                NaN               NaN              NaN              NaN
# 4422                NaN               NaN              NaN              NaN
# 4423                NaN               NaN              NaN              NaN
# 4424                NaN               NaN              NaN              NaN
# 4425                NaN               NaN              NaN              NaN
#
#      shot_outcome_name shot_first_time  shot_type_id shot_type_name  \
# 0                  NaN             NaN           NaN            NaN
# 1                  NaN             NaN           NaN            NaN
# 2                  NaN             NaN           NaN            NaN
# 3                  NaN             NaN           NaN            NaN
# 4                  NaN             NaN           NaN            NaN
# ...                ...             ...           ...            ...
# 4421               NaN             NaN           NaN            NaN
# 4422               NaN             NaN           NaN            NaN
# 4423               NaN             NaN           NaN            NaN
# 4424               NaN             NaN           NaN            NaN
# 4425               NaN             NaN           NaN            NaN
#
#       shot_technique_id shot_technique_name  shot_body_part_id  \
# 0                   NaN                 NaN                NaN
# 1                   NaN                 NaN                NaN
# 2                   NaN                 NaN                NaN
# 3                   NaN                 NaN                NaN
# 4                   NaN                 NaN                NaN
# ...                 ...                 ...                ...
# 4421                NaN                 NaN                NaN
# 4422                NaN                 NaN                NaN
# 4423                NaN                 NaN                NaN
# 4424                NaN                 NaN                NaN
# 4425                NaN                 NaN                NaN
#
#      shot_body_part_name shot_freeze_frame  goalkeeper_outcome_id  \
# 0                    NaN               NaN                    NaN
# 1                    NaN               NaN                    NaN
# 2                    NaN               NaN                    NaN
# 3                    NaN               NaN                    NaN
# 4                    NaN               NaN                    NaN
# ...                  ...               ...                    ...
# 4421                 NaN               NaN                    NaN
# 4422                 NaN               NaN                    NaN
# 4423                 NaN               NaN                    NaN
# 4424                 NaN               NaN                    NaN
# 4425                 NaN               NaN                    NaN
#
#      goalkeeper_outcome_name  goalkeeper_type_id goalkeeper_type_name  \
# 0                        NaN                 NaN                  NaN
# 1                        NaN                 NaN                  NaN
# 2                        NaN                 NaN                  NaN
# 3                        NaN                 NaN                  NaN
# 4                        NaN                 NaN                  NaN
# ...                      ...                 ...                  ...
# 4421                     NaN                 NaN                  NaN
# 4422                     NaN                 NaN                  NaN
# 4423                     NaN                 NaN                  NaN
# 4424                     NaN                 NaN                  NaN
# 4425                     NaN                 NaN                  NaN
#
#       goalkeeper_position_id goalkeeper_position_name pass_backheel  \
# 0                        NaN                      NaN           NaN
# 1                        NaN                      NaN           NaN
# 2                        NaN                      NaN           NaN
# 3                        NaN                      NaN           NaN
# 4                        NaN                      NaN           NaN
# ...                      ...                      ...           ...
# 4421                     NaN                      NaN           NaN
# 4422                     NaN                      NaN           NaN
# 4423                     NaN                      NaN           NaN
# 4424                     NaN                      NaN           NaN
# 4425                     NaN                      NaN           NaN
#
#      dribble_overrun ball_recovery_offensive pass_aerial_won  \
# 0                NaN                     NaN             NaN
# 1                NaN                     NaN             NaN
# 2                NaN                     NaN             NaN
# 3                NaN                     NaN             NaN
# 4                NaN                     NaN             NaN
# ...              ...                     ...             ...
# 4421             NaN                     NaN             NaN
# 4422             NaN                     NaN             NaN
# 4423             NaN                     NaN             NaN
# 4424             NaN                     NaN             NaN
# 4425             NaN                     NaN             NaN
#
#      foul_committed_advantage foul_won_advantage pass_shot_assist  \
# 0                         NaN                NaN              NaN
# 1                         NaN                NaN              NaN
# 2                         NaN                NaN              NaN
# 3                         NaN                NaN              NaN
# 4                         NaN                NaN              NaN
# ...                       ...                ...              ...
# 4421                      NaN                NaN              NaN
# 4422                      NaN                NaN              NaN
# 4423                      NaN                NaN              NaN
# 4424                      NaN                NaN              NaN
# 4425                      NaN                NaN              NaN
#
#      goalkeeper_end_location ball_recovery_recovery_failure shot_deflected  \
# 0                        NaN                            NaN            NaN
# 1                        NaN                            NaN            NaN
# 2                        NaN                            NaN            NaN
# 3                        NaN                            NaN            NaN
# 4                        NaN                            NaN            NaN
# ...                      ...                            ...            ...
# 4421                     NaN                            NaN            NaN
# 4422                     NaN                            NaN            NaN
# 4423                     NaN                            NaN            NaN
# 4424                     NaN                            NaN            NaN
# 4425                     NaN                            NaN            NaN
#
#      block_deflection  goalkeeper_technique_id goalkeeper_technique_name  \
# 0                 NaN                      NaN                       NaN
# 1                 NaN                      NaN                       NaN
# 2                 NaN                      NaN                       NaN
# 3                 NaN                      NaN                       NaN
# 4                 NaN                      NaN                       NaN
# ...               ...                      ...                       ...
# 4421              NaN                      NaN                       NaN
# 4422              NaN                      NaN                       NaN
# 4423              NaN                      NaN                       NaN
# 4424              NaN                      NaN                       NaN
# 4425              NaN                      NaN                       NaN
#
#       goalkeeper_body_part_id goalkeeper_body_part_name pass_switch  \
# 0                         NaN                       NaN         NaN
# 1                         NaN                       NaN         NaN
# 2                         NaN                       NaN         NaN
# 3                         NaN                       NaN         NaN
# 4                         NaN                       NaN         NaN
# ...                       ...                       ...         ...
# 4421                      NaN                       NaN         NaN
# 4422                      NaN                       NaN         NaN
# 4423                      NaN                       NaN         NaN
# 4424                      NaN                       NaN         NaN
# 4425                      NaN                       NaN         NaN
#
#      shot_aerial_won foul_won_defensive pass_deflected shot_redirect  \
# 0                NaN                NaN            NaN           NaN
# 1                NaN                NaN            NaN           NaN
# 2                NaN                NaN            NaN           NaN
# 3                NaN                NaN            NaN           NaN
# 4                NaN                NaN            NaN           NaN
# ...              ...                ...            ...           ...
# 4421             NaN                NaN            NaN           NaN
# 4422             NaN               True            NaN           NaN
# 4423             NaN                NaN            NaN           NaN
# 4424             NaN                NaN            NaN           NaN
# 4425             NaN                NaN            NaN           NaN
#
#       substitution_outcome_id substitution_outcome_name  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ...                       ...                       ...
# 4421                      NaN                       NaN
# 4422                      NaN                       NaN
# 4423                      NaN                       NaN
# 4424                      NaN                       NaN
# 4425                      NaN                       NaN
#
#       substitution_replacement_id substitution_replacement_name  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ...                           ...                           ...
# 4421                          NaN                           NaN
# 4422                          NaN                           NaN
# 4423                          NaN                           NaN
# 4424                          NaN                           NaN
# 4425                          NaN                           NaN
#
#       foul_committed_card_id foul_committed_card_name pass_cut_back  \
# 0                        NaN                      NaN           NaN
# 1                        NaN                      NaN           NaN
# 2                        NaN                      NaN           NaN
# 3                        NaN                      NaN           NaN
# 4                        NaN                      NaN           NaN
# ...                      ...                      ...           ...
# 4421                     NaN                      NaN           NaN
# 4422                     NaN                      NaN           NaN
# 4423                     NaN                      NaN           NaN
# 4424                     NaN                      NaN           NaN
# 4425                     NaN                      NaN           NaN
#
#      shot_one_on_one block_save_block  foul_committed_type_id  \
# 0                NaN              NaN                     NaN
# 1                NaN              NaN                     NaN
# 2                NaN              NaN                     NaN
# 3                NaN              NaN                     NaN
# 4                NaN              NaN                     NaN
# ...              ...              ...                     ...
# 4421             NaN              NaN                     NaN
# 4422             NaN              NaN                     NaN
# 4423             NaN              NaN                     NaN
# 4424             NaN              NaN                     NaN
# 4425             NaN              NaN                     NaN
#
#      foul_committed_type_name foul_committed_offensive  bad_behaviour_card_id  \
# 0                         NaN                      NaN                    NaN
# 1                         NaN                      NaN                    NaN
# 2                         NaN                      NaN                    NaN
# 3                         NaN                      NaN                    NaN
# 4                         NaN                      NaN                    NaN
# ...                       ...                      ...                    ...
# 4421                      NaN                      NaN                    NaN
# 4422                      NaN                      NaN                    NaN
# 4423                      NaN                      NaN                    7.0
# 4424                      NaN                      NaN                    NaN
# 4425                      NaN                      NaN                    NaN
#
#      bad_behaviour_card_name
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 4421                     NaN
# 4422                     NaN
# 4423             Yellow Card
# 4424                     NaN
# 4425                     NaN
#
# [4426 rows x 107 columns]

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
for i in match_8657.columns:
    print('-----------INICIO-------------')
    print(match_8657[i].value_counts())
    print('-----------FIM-------------')
# Out:
# -----------INICIO-------------
# 04198d50-c681-4522-a809-683dea2e8f18    1
# 19d853b8-38ff-441f-980b-dd7369a5d38f    1
# 1d9a4a8e-66bd-46e9-8edd-a87411191595    1
# 7949d424-84f7-440e-bcea-bb629a746cdb    1
# 915b9c8f-ab85-4151-9da3-aa59d656da2b    1
#                                        ..
# a72d4bae-7aaf-4ca7-88d1-40aae1d80966    1
# 98ef66a0-1f5e-48c5-ad74-a1aa65aeb513    1
# 7f372394-d4a1-4819-a756-a4f1d2e12b48    1
# caa96907-5f34-46a5-ae42-011e637b0b02    1
# 11c762e6-8fb0-4342-98d4-f6505f99aa25    1
# Name: id, Length: 4426, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 1       1
# 2949    1
# 2955    1
# 2954    1
# 2953    1
#        ..
# 1482    1
# 1483    1
# 1484    1
# 1485    1
# 4426    1
# Name: index, Length: 4426, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 1    2413
# 2    2013
# Name: period, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 00:00:00.000    8
# 00:03:48.191    3
# 00:07:56.653    3
# 00:15:58.618    3
# 00:20:30.613    3
#                ..
# 00:15:36.573    1
# 00:00:30.951    1
# 00:15:37.413    1
# 00:00:28.431    1
# 00:43:24.450    1
# Name: timestamp, Length: 3087, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 45    100
# 29     96
# 22     91
# 15     88
# 78     82
#      ...
# 51     10
# 71      9
# 50      8
# 36      5
# 93      3
# Name: minute, Length: 94, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 8     92
# 58    91
# 46    91
# 15    87
# 52    87
# 23    86
# 30    84
# 28    84
# 5     84
# 35    84
# 0     83
# 22    82
# 12    82
# 16    81
# 2     81
# 39    81
# 18    81
# 56    80
# 14    80
# 6     79
# 51    79
# 34    77
# 10    77
# 1     77
# 37    77
# 33    77
# 38    76
# 29    75
# 7     74
# 3     74
# 25    73
# 59    73
# 48    72
# 19    72
# 17    71
# 53    71
# 45    70
# 21    70
# 9     70
# 13    69
# 50    69
# 43    69
# 4     67
# 27    67
# 54    67
# 41    67
# 44    66
# 57    65
# 11    65
# 24    64
# 49    63
# 55    63
# 31    63
# 47    62
# 36    62
# 26    62
# 20    62
# 32    59
# 42    56
# 40    54
# Name: second, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 52     151
# 141    140
# 43     125
# 39     116
# 31     110
#       ...
# 106      2
# 5        2
# 88       2
# 36       2
# 131      1
# Name: possession, Length: 151, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 0.000    104
# 0.680     67
# 0.760     64
# 0.800     62
# 0.600     58
#         ...
# 2.282      1
# 1.380      1
# 2.168      1
# 8.083      1
# 3.719      1
# Name: duration, Length: 665, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 30    1184
# 42    1162
# 43    1122
# 17     533
# 2       73
# 14      38
# 5       31
# 23      29
# 9       29
# 6       28
# 4       28
# 39      27
# 16      26
# 10      22
# 22      16
# 21      15
# 38      15
# 3       12
# 29      11
# 19       6
# 18       4
# 34       4
# 36       2
# 35       2
# 33       2
# 24       2
# 26       1
# 27       1
# 40       1
# Name: type_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Pass               1184
# Ball Receipt*      1162
# Carry              1122
# Pressure            533
# Ball Recovery        73
# Dribble              38
# Camera On            31
# Goal Keeper          29
# Clearance            29
# Block                28
# Duel                 28
# Dribbled Past        27
# Shot                 26
# Interception         22
# Foul Committed       16
# Foul Won             15
# Miscontrol           15
# Dispossessed         12
# Camera off           11
# Substitution          6
# Half Start            4
# Half End              4
# Tactical Shift        2
# Starting XI           2
# 50/50                 2
# Bad Behaviour         2
# Player On             1
# Player Off            1
# Injury Stoppage       1
# Name: type_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 768    2484
# 782    1942
# Name: possession_team_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# England    2484
# Belgium    1942
# Name: possession_team_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 1    3164
# 4     800
# 3     140
# 7     125
# 9      87
# 2      51
# 8      34
# 6      25
# Name: play_pattern_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Regular Play      3164
# From Throw In      800
# From Free Kick     140
# From Goal Kick     125
# From Kick Off       87
# From Corner         51
# From Keeper         34
# From Counter        25
# Name: play_pattern_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 768    2495
# 782    1931
# Name: team_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# England    2495
# Belgium    1931
# Name: team_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 343.0    2
# 352.0    2
# Name: tactics_formation, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# [{'player': {'id': 3509, 'name': 'Thibaut Courtois'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'jersey_number': 1}, {'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'jersey_number': 2}, {'player': {'id': 3101, 'name': 'Vincent Kompany'}, 'position': {'id': 4, 'name': 'Center Back'}, 'jersey_number': 4}, {'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'jersey_number': 5}, {'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'jersey_number': 15}, {'player': {'id': 4831, 'name': 'Nacer Chadli'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'jersey_number': 22}, {'player': {'id': 2954, 'name': 'Youri Tielemans'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'jersey_number': 17}, {'player': {'id': 5642, 'name': 'Axel Witsel'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'jersey_number': 6}, {'player': {'id': 3089, 'name': 'Kevin De Bruyne'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'jersey_number': 7}, {'player': {'id': 3621, 'name': 'Eden Hazard'}, 'position': {'id': 21, 'name': 'Left Wing'}, 'jersey_number': 10}, {'player': {'id': 3289, 'name': 'Romelu Lukaku Menama'}, 'position': {'id': 23, 'name': 'Center Forward'}, 'jersey_number': 9}]             1
# [{'player': {'id': 3468, 'name': 'Jordan Pickford'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'jersey_number': 1}, {'player': {'id': 3314, 'name': 'Phil Jones'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'jersey_number': 16}, {'player': {'id': 3244, 'name': 'John Stones'}, 'position': {'id': 4, 'name': 'Center Back'}, 'jersey_number': 5}, {'player': {'id': 3336, 'name': 'Harry Maguire'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'jersey_number': 6}, {'player': {'id': 3308, 'name': 'Kieran Trippier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'jersey_number': 12}, {'player': {'id': 3594, 'name': 'Danny Rose'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'jersey_number': 3}, {'player': {'id': 10956, 'name': 'Eric Dier'}, 'position': {'id': 10, 'name': 'Center Defensive Midfield'}, 'jersey_number': 4}, {'player': {'id': 3504, 'name': 'Ruben Loftus-Cheek'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'jersey_number': 21}, {'player': {'id': 4597, 'name': 'Fabian Delph'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'jersey_number': 17}, {'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'jersey_number': 9}, {'player': {'id': 3233, 'name': 'Raheem Sterling'}, 'position': {'id': 24, 'name': 'Left Center Forward'}, 'jersey_number': 10}]       1
# [{'player': {'id': 3509, 'name': 'Thibaut Courtois'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'jersey_number': 1}, {'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'jersey_number': 2}, {'player': {'id': 3101, 'name': 'Vincent Kompany'}, 'position': {'id': 4, 'name': 'Center Back'}, 'jersey_number': 4}, {'player': {'id': 6332, 'name': 'Thomas Vermaelen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'jersey_number': 3}, {'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'jersey_number': 15}, {'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'jersey_number': 5}, {'player': {'id': 2954, 'name': 'Youri Tielemans'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'jersey_number': 17}, {'player': {'id': 5642, 'name': 'Axel Witsel'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'jersey_number': 6}, {'player': {'id': 3089, 'name': 'Kevin De Bruyne'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'jersey_number': 7}, {'player': {'id': 3621, 'name': 'Eden Hazard'}, 'position': {'id': 21, 'name': 'Left Wing'}, 'jersey_number': 10}, {'player': {'id': 3289, 'name': 'Romelu Lukaku Menama'}, 'position': {'id': 23, 'name': 'Center Forward'}, 'jersey_number': 9}]          1
# [{'player': {'id': 3468, 'name': 'Jordan Pickford'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'jersey_number': 1}, {'player': {'id': 3314, 'name': 'Phil Jones'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'jersey_number': 16}, {'player': {'id': 3244, 'name': 'John Stones'}, 'position': {'id': 4, 'name': 'Center Back'}, 'jersey_number': 5}, {'player': {'id': 3336, 'name': 'Harry Maguire'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'jersey_number': 6}, {'player': {'id': 3308, 'name': 'Kieran Trippier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'jersey_number': 12}, {'player': {'id': 4597, 'name': 'Fabian Delph'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'jersey_number': 17}, {'player': {'id': 10956, 'name': 'Eric Dier'}, 'position': {'id': 10, 'name': 'Center Defensive Midfield'}, 'jersey_number': 4}, {'player': {'id': 3504, 'name': 'Ruben Loftus-Cheek'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'jersey_number': 21}, {'player': {'id': 3293, 'name': 'Jesse Lingard'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'jersey_number': 7}, {'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'jersey_number': 9}, {'player': {'id': 3318, 'name': 'Marcus Rashford'}, 'position': {'id': 24, 'name': 'Left Center Forward'}, 'jersey_number': 19}]    1
# Name: tactics_lineup, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# [5a68d8ba-5882-4602-a5a4-a558e295d7a5]                                                                                3
# [69e4425c-dbf4-4fa0-a576-59e48d0e7b03]                                                                                3
# [427d36e9-ff82-4c0d-878a-8ab226ab9458]                                                                                3
# [23a26673-e44b-4edc-b96a-ebeb53ed8cf8]                                                                                2
# [e7dc808d-7eb1-474e-a679-fa8e76b35bda]                                                                                2
#                                                                                                                      ..
# [98ef66a0-1f5e-48c5-ad74-a1aa65aeb513]                                                                                1
# [7cbdc6b6-602a-409a-ab62-77c40da49777, 7f372394-d4a1-4819-a756-a4f1d2e12b48, c156ddb1-eb75-49aa-8d7b-cb6293131227]    1
# [7cbdc6b6-602a-409a-ab62-77c40da49777, caa96907-5f34-46a5-ae42-011e637b0b02]                                          1
# [aed5b6a4-0119-4534-8455-3584a87b0033, c156ddb1-eb75-49aa-8d7b-cb6293131227]                                          1
# [dba9a8bc-158b-4578-b98a-653145a3292f]                                                                                1
# Name: related_events, Length: 4149, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# [76.0, 5.0]      8
# [74.0, 59.0]     7
# [76.0, 77.0]     7
# [75.0, 73.0]     7
# [76.0, 75.0]     7
#                 ..
# [101.0, 24.0]    1
# [87.0, 33.0]     1
# [33.0, 37.0]     1
# [35.0, 41.0]     1
# [57.0, 62.0]     1
# Name: location, Length: 2472, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 3308.0     300
# 10956.0    298
# 3244.0     278
# 4597.0     276
# 3089.0     248
# 3621.0     236
# 3314.0     220
# 3504.0     211
# 3336.0     206
# 5642.0     202
# 2954.0     195
# 20005.0    188
# 3077.0     182
# 3293.0     136
# 3101.0     133
# 3176.0     129
# 10955.0    126
# 3233.0     125
# 3318.0     108
# 3594.0      96
# 3509.0      93
# 3289.0      83
# 6332.0      68
# 4831.0      61
# 3468.0      60
# 5630.0      54
# 3037.0      34
# 3094.0      25
# Name: player_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Kieran Trippier            300
# Eric Dier                  298
# John Stones                278
# Fabian Delph               276
# Kevin De Bruyne            248
# Eden Hazard                236
# Phil Jones                 220
# Ruben Loftus-Cheek         211
# Harry Maguire              206
# Axel Witsel                202
# Youri Tielemans            195
# Toby Alderweireld          188
# Jan Vertonghen             182
# Jesse Lingard              136
# Vincent Kompany            133
# Thomas Meunier             129
# Harry Kane                 126
# Raheem Sterling            125
# Marcus Rashford            108
# Danny Rose                  96
# Thibaut Courtois            93
# Romelu Lukaku Menama        83
# Thomas Vermaelen            68
# Nacer Chadli                61
# Jordan Pickford             60
# Dries Mertens               54
# Mousa Sidi Yaya Dembélé     34
# Bamidele Alli               25
# Name: player_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 7.0     429
# 4.0     411
# 3.0     408
# 5.0     344
# 8.0     342
# 15.0    339
# 10.0    298
# 17.0    248
# 13.0    236
# 21.0    236
# 24.0    233
# 9.0     229
# 11.0    202
# 1.0     153
# 23.0    137
# 22.0    126
# Name: position_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Right Wing Back              429
# Center Back                  411
# Right Center Back            408
# Left Center Back             344
# Left Wing Back               342
# Left Center Midfield         339
# Center Defensive Midfield    298
# Right Wing                   248
# Right Center Midfield        236
# Left Wing                    236
# Left Center Forward          233
# Right Defensive Midfield     229
# Left Defensive Midfield      202
# Goalkeeper                   153
# Center Forward               137
# Right Center Forward         126
# Name: position_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 10956.0    83
# 3308.0     80
# 4597.0     75
# 3244.0     73
# 3089.0     70
# 3621.0     66
# 3336.0     58
# 3504.0     58
# 3314.0     57
# 20005.0    54
# 5642.0     49
# 10955.0    45
# 2954.0     43
# 3077.0     42
# 3233.0     38
# 3293.0     35
# 3176.0     34
# 3101.0     33
# 3318.0     33
# 3289.0     31
# 3594.0     22
# 5630.0     16
# 3509.0     15
# 4831.0     13
# 6332.0     13
# 3468.0     13
# 3037.0      7
# 3094.0      6
# Name: pass_recipient_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Eric Dier                  83
# Kieran Trippier            80
# Fabian Delph               75
# John Stones                73
# Kevin De Bruyne            70
# Eden Hazard                66
# Harry Maguire              58
# Ruben Loftus-Cheek         58
# Phil Jones                 57
# Toby Alderweireld          54
# Axel Witsel                49
# Harry Kane                 45
# Youri Tielemans            43
# Jan Vertonghen             42
# Raheem Sterling            38
# Jesse Lingard              35
# Thomas Meunier             34
# Vincent Kompany            33
# Marcus Rashford            33
# Romelu Lukaku Menama       31
# Danny Rose                 22
# Dries Mertens              16
# Thibaut Courtois           15
# Nacer Chadli               13
# Thomas Vermaelen           13
# Jordan Pickford            13
# Mousa Sidi Yaya Dembélé     7
# Bamidele Alli               6
# Name: pass_recipient_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 9.219544     26
# 8.062258     21
# 12.041595    19
# 10.000000    16
# 13.601471    14
#              ..
# 28.425340     1
# 36.124783     1
# 33.301650     1
# 2.828427      1
# 27.459060     1
# Name: pass_length, Length: 388, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# -1.570796    27
#  0.000000    23
#  3.141593    17
#  1.570796    16
#  0.785398    11
#              ..
# -2.003204     1
# -0.499347     1
#  1.377585     1
#  2.743070     1
# -0.046478     1
# Name: pass_angle, Length: 662, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 1.0    980
# 3.0    136
# 2.0     68
# Name: pass_height_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Ground Pass    980
# High Pass      136
# Low Pass        68
# Name: pass_height_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# [73.0, 5.0]     4
# [63.0, 25.0]    4
# [48.0, 26.0]    3
# [76.0, 75.0]    3
# [76.0, 5.0]     3
#                ..
# [75.0, 66.0]    1
# [79.0, 61.0]    1
# [71.0, 63.0]    1
# [75.0, 57.0]    1
# [55.0, 75.0]    1
# Name: pass_end_location, Length: 1054, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 66.0    53
# 67.0    18
# 62.0     9
# 61.0     9
# 63.0     6
# 64.0     3
# 65.0     2
# Name: pass_type_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Recovery        53
# Throw-in        18
# Free Kick        9
# Corner           9
# Goal Kick        6
# Interception     3
# Kick Off         2
# Name: pass_type_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 40.0    859
# 38.0    264
# 37.0     26
# 69.0     12
# 70.0      2
# Name: pass_body_part_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Right Foot    859
# Left Foot     264
# Head           26
# Keeper Arm     12
# Other           2
# Name: pass_body_part_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    991
# Name: under_pressure, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# [75.0, 75.0]    3
# [65.0, 53.0]    3
# [79.0, 77.0]    3
# [71.0, 63.0]    3
# [75.0, 8.0]     3
#                ..
# [67.0, 68.0]    1
# [71.0, 71.0]    1
# [79.0, 63.0]    1
# [22.0, 17.0]    1
# [12.0, 77.0]    1
# Name: carry_end_location, Length: 1021, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 9.0     123
# 75.0     10
# 77.0      4
# 76.0      1
# Name: pass_outcome_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Incomplete      123
# Out              10
# Unknown           4
# Pass Offside      1
# Name: pass_outcome_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 9.0    116
# Name: ball_receipt_outcome_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Incomplete    116
# Name: ball_receipt_outcome_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 4.0     11
# 16.0     6
# 13.0     3
# 14.0     2
# Name: interception_outcome_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Won                11
# Success In Play     6
# Lost In Play        3
# Lost Out            2
# Name: interception_outcome_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    91
# Name: counterpress, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 4.0     8
# 16.0    6
# 13.0    5
# 14.0    4
# Name: duel_outcome_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Won                8
# Success In Play    6
# Lost In Play       5
# Lost Out           4
# Name: duel_outcome_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 11.0    23
# 10.0     5
# Name: duel_type_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Tackle         23
# Aerial Lost     5
# Name: duel_type_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 8.0    24
# 9.0    14
# Name: dribble_outcome_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Complete      24
# Incomplete    14
# Name: dribble_outcome_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 1.0    1
# 3.0    1
# Name: 50_50_outcome_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Lost               1
# Success To Team    1
# Name: 50_50_outcome_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    29
# Name: pass_cross, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 5aa3cae9-f30d-4616-a556-f7faeae8f309    1
# 6f5ca1ea-86f5-492a-83de-77b881d0c2b0    1
# c8f14ba2-59a9-43bc-bda7-16872e96f1ac    1
# c42f704c-6978-4e59-99d7-c19c75bbe62e    1
# 58640053-0593-44e0-bd35-a854ffe6ae18    1
# 76053023-ee63-4622-ae8b-ba89c9c13a9f    1
# e4cd8174-ffbb-4ef0-a362-e7ec554b22cc    1
# e8a0a00d-725f-40af-8836-7dffb7a1c711    1
# efc3dbaf-e4b9-4a30-8989-01bca30f2253    1
# cabc2c3b-19ce-4714-bc7c-152309db0e8b    1
# b94010f4-1d05-4f65-a86e-7b75c301a73a    1
# dc04cb35-1aec-42a9-9607-91373aafb64c    1
# 3c798069-fb5c-46a8-b20a-ad1b9a53a757    1
# eb357d72-4f7d-41ad-81eb-c8e230ae6642    1
# e69daa52-3779-4ebc-9f09-36e24aaf0148    1
# c0b23d3e-abfd-44de-a82f-6f5db8b0a56a    1
# f0402397-2845-4846-82a4-67ae4d0f5c2d    1
# efa3f913-cd2c-4118-8e03-6b7edcd2bac2    1
# 9971f836-6f12-45ac-a54b-c62576d1d041    1
# 946c12b3-d688-42e2-a988-93634b2dc572    1
# 1571b0bf-a7a0-47fc-b82d-12405cd43f50    1
# cbe0b1c1-18c2-4771-80be-58ea67462b32    1
# af5d7bca-a18c-4790-ad80-e04062c4c81e    1
# ebe22aaa-c8c7-4920-8b9f-4cbdb3e39b3e    1
# Name: pass_assisted_shot_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    2
# Name: pass_goal_assist, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 0.297618    1
# 0.059820    1
# 0.041474    1
# 0.054585    1
# 0.064849    1
# 0.029848    1
# 0.054670    1
# 0.064027    1
# 0.256255    1
# 0.029425    1
# 0.025311    1
# 0.021512    1
# 0.023827    1
# 0.097811    1
# 0.038014    1
# 0.049434    1
# 0.032294    1
# 0.077758    1
# 0.033633    1
# 0.028621    1
# 0.107728    1
# 0.014484    1
# 0.050740    1
# 0.017406    1
# 0.057015    1
# 0.337615    1
# Name: shot_statsbomb_xg, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# [120.0, 41.9, 0.4]    1
# [101.0, 53.0]         1
# [119.0, 37.2, 0.8]    1
# [119.0, 36.8, 1.6]    1
# [120.0, 46.9, 0.3]    1
# [120.0, 35.2, 0.5]    1
# [120.0, 34.6, 0.2]    1
# [120.0, 32.5, 0.2]    1
# [119.0, 42.0]         1
# [118.0, 36.6, 0.2]    1
# [112.0, 31.0]         1
# [109.0, 58.0]         1
# [120.0, 33.5, 0.4]    1
# [106.0, 30.0]         1
# [106.0, 50.0]         1
# [120.0, 38.3, 3.8]    1
# [110.0, 34.0]         1
# [108.0, 48.0]         1
# [100.0, 40.0]         1
# [120.0, 48.9, 2.4]    1
# [120.0, 33.7, 1.6]    1
# [119.0, 40.1, 0.2]    1
# [119.0, 40.1, 1.9]    1
# [119.0, 41.1, 0.1]    1
# [119.0, 39.5, 1.1]    1
# [120.0, 36.6, 0.8]    1
# Name: shot_end_location, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# ad1837d5-658e-4fcd-9dec-b5058a699e8b    1
# f6bf8734-d1c9-45af-8139-c8854d91a309    1
# 337221fc-60c7-4827-9ca0-244d0043d3fe    1
# 7abd94d5-3f8c-462f-b801-d3e6ef809b39    1
# 59b85292-0f49-4b6e-b889-79bf07c027e1    1
# b2112943-5cde-41da-9363-1b21d99470e2    1
# 217e1918-913b-45d4-bc09-5238268e3574    1
# f1c9a078-e443-4cdb-9287-538f5ac6c36f    1
# 55300bea-3806-4030-98f6-44c550ef5e0c    1
# 1367870f-78ea-4333-8d68-9cfa21825b86    1
# 2ba644eb-8266-43ad-a293-9a2636110fa7    1
# 2e933988-94f2-4010-9944-101c4ccf55fd    1
# 9f944dfd-ac0d-4162-b634-5cc40c9107eb    1
# 863840ec-9e8b-4bf3-900e-334512ad0b00    1
# f3cc35e3-8e0b-432a-9a33-f53400e4575f    1
# a047979a-659a-4b74-b6f1-7f52bfd5e94c    1
# 34897ec8-3e55-4a45-859b-b45e8bd6dc5b    1
# 3c95e9d0-775d-453b-b298-197044c2dea3    1
# 8f11d567-9ff1-40bb-adfa-da4d4f42f0ca    1
# 0bcc714b-e483-4bbb-9f35-89651149b922    1
# 711f09b5-1dcb-4ab8-8e76-e65b6791a9b3    1
# 5bffebb9-6ddd-4f76-86cb-2c82112f0464    1
# 6bcb400c-64d7-4ea1-9fa4-fa571f0cbd41    1
# 79fa1bf5-5402-4eb7-8ed0-62752b27bc44    1
# Name: shot_key_pass_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 98.0     8
# 96.0     7
# 100.0    7
# 97.0     2
# 101.0    2
# Name: shot_outcome_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Off T      8
# Blocked    7
# Saved      7
# Goal       2
# Wayward    2
# Name: shot_outcome_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    7
# Name: shot_first_time, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 87.0    26
# Name: shot_type_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Open Play    26
# Name: shot_type_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 93.0    19
# 95.0     4
# 91.0     2
# 92.0     1
# Name: shot_technique_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Normal         19
# Volley          4
# Half Volley     2
# Lob             1
# Name: shot_technique_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 40.0    19
# 37.0     5
# 38.0     2
# Name: shot_body_part_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Right Foot    19
# Head           5
# Left Foot      2
# Name: shot_body_part_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# [{'location': [112.0, 42.0], 'player': {'id': 3594, 'name': 'Danny Rose'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [118.0, 40.0], 'player': {'id': 3468, 'name': 'Jordan Pickford'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [108.0, 43.0], 'player': {'id': 3336, 'name': 'Harry Maguire'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [112.0, 36.0], 'player': {'id': 3244, 'name': 'John Stones'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [107.0, 26.0], 'player': {'id': 3314, 'name': 'Phil Jones'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [103.0, 38.0], 'player': {'id': 3089, 'name': 'Kevin De Bruyne'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'teammate': True}, {'location': [113.0, 21.0], 'player': {'id': 3308, 'name': 'Kieran Trippier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [113.0, 13.0], 'player': {'id': 4831, 'name': 'Nacer Chadli'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': True}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# [{'location': [105.0, 72.0], 'player': {'id': 3308, 'name': 'Kieran Trippier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': True}, {'location': [117.0, 43.0], 'player': {'id': 3509, 'name': 'Thibaut Courtois'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [96.0, 24.0], 'player': {'id': 3594, 'name': 'Danny Rose'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': True}, {'location': [106.0, 28.0], 'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [110.0, 45.0], 'player': {'id': 4597, 'name': 'Fabian Delph'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'teammate': True}, {'location': [105.0, 43.0], 'player': {'id': 2954, 'name': 'Youri Tielemans'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'teammate': False}, {'location': [106.0, 46.0], 'player': {'id': 5642, 'name': 'Axel Witsel'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'teammate': False}, {'location': [103.0, 53.0], 'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [106.0, 58.0], 'player': {'id': 3504, 'name': 'Ruben Loftus-Cheek'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': True}, {'location': [107.0, 58.0], 'player': {'id': 4831, 'name': 'Nacer Chadli'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [105.0, 61.0], 'player': {'id': 3101, 'name': 'Vincent Kompany'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [106.0, 35.0], 'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [106.0, 32.0], 'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'teammate': True}]                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# [{'location': [110.0, 44.0], 'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'teammate': True}, {'location': [103.0, 4.0], 'player': {'id': 4597, 'name': 'Fabian Delph'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': True}, {'location': [93.0, 34.0], 'player': {'id': 3089, 'name': 'Kevin De Bruyne'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'teammate': False}, {'location': [99.0, 49.0], 'player': {'id': 5630, 'name': 'Dries Mertens'}, 'position': {'id': 23, 'name': 'Center Forward'}, 'teammate': False}, {'location': [102.0, 22.0], 'player': {'id': 3037, 'name': 'Mousa Sidi Yaya Dembélé'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'teammate': False}, {'location': [108.0, 20.0], 'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [108.0, 47.0], 'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [111.0, 41.0], 'player': {'id': 6332, 'name': 'Thomas Vermaelen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [106.0, 40.0], 'player': {'id': 3101, 'name': 'Vincent Kompany'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [108.0, 37.0], 'player': {'id': 3293, 'name': 'Jesse Lingard'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'teammate': True}, {'location': [105.0, 33.0], 'player': {'id': 5642, 'name': 'Axel Witsel'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'teammate': False}, {'location': [117.0, 38.0], 'player': {'id': 3509, 'name': 'Thibaut Courtois'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [104.0, 40.0], 'player': {'id': 3504, 'name': 'Ruben Loftus-Cheek'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': True}, {'location': [109.0, 31.0], 'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}]                                                                                                                                                                                                                                                                                      1
# [{'location': [119.0, 44.0], 'player': {'id': 3468, 'name': 'Jordan Pickford'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [115.0, 40.0], 'player': {'id': 3244, 'name': 'John Stones'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [112.0, 35.0], 'player': {'id': 3308, 'name': 'Kieran Trippier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [108.0, 27.0], 'player': {'id': 3621, 'name': 'Eden Hazard'}, 'position': {'id': 21, 'name': 'Left Wing'}, 'teammate': True}, {'location': [105.0, 28.0], 'player': {'id': 5630, 'name': 'Dries Mertens'}, 'position': {'id': 23, 'name': 'Center Forward'}, 'teammate': True}, {'location': [106.0, 36.0], 'player': {'id': 3314, 'name': 'Phil Jones'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [96.0, 35.0], 'player': {'id': 3336, 'name': 'Harry Maguire'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [100.0, 49.0], 'player': {'id': 3089, 'name': 'Kevin De Bruyne'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'teammate': True}, {'location': [109.0, 50.0], 'player': {'id': 4597, 'name': 'Fabian Delph'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# [{'location': [97.0, 37.0], 'player': {'id': 3089, 'name': 'Kevin De Bruyne'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'teammate': True}, {'location': [112.0, 28.0], 'player': {'id': 3621, 'name': 'Eden Hazard'}, 'position': {'id': 21, 'name': 'Left Wing'}, 'teammate': True}, {'location': [119.0, 40.0], 'player': {'id': 3468, 'name': 'Jordan Pickford'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [112.0, 30.0], 'player': {'id': 3314, 'name': 'Phil Jones'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [106.0, 30.0], 'player': {'id': 3244, 'name': 'John Stones'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [102.0, 43.0], 'player': {'id': 4597, 'name': 'Fabian Delph'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [108.0, 38.0], 'player': {'id': 10956, 'name': 'Eric Dier'}, 'position': {'id': 10, 'name': 'Center Defensive Midfield'}, 'teammate': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# [{'location': [118.0, 39.0], 'player': {'id': 3509, 'name': 'Thibaut Courtois'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [111.0, 42.0], 'player': {'id': 3244, 'name': 'John Stones'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': True}, {'location': [106.0, 44.0], 'player': {'id': 3504, 'name': 'Ruben Loftus-Cheek'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': True}, {'location': [104.0, 37.0], 'player': {'id': 3318, 'name': 'Marcus Rashford'}, 'position': {'id': 24, 'name': 'Left Center Forward'}, 'teammate': True}, {'location': [99.0, 42.0], 'player': {'id': 2954, 'name': 'Youri Tielemans'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'teammate': False}, {'location': [96.0, 51.0], 'player': {'id': 3621, 'name': 'Eden Hazard'}, 'position': {'id': 21, 'name': 'Left Wing'}, 'teammate': False}, {'location': [105.0, 47.0], 'player': {'id': 3089, 'name': 'Kevin De Bruyne'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'teammate': False}, {'location': [109.0, 44.0], 'player': {'id': 5642, 'name': 'Axel Witsel'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'teammate': False}, {'location': [110.0, 40.0], 'player': {'id': 6332, 'name': 'Thomas Vermaelen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [107.0, 42.0], 'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [109.0, 36.0], 'player': {'id': 3101, 'name': 'Vincent Kompany'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [111.0, 31.0], 'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [111.0, 34.0], 'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [109.0, 38.0], 'player': {'id': 10956, 'name': 'Eric Dier'}, 'position': {'id': 10, 'name': 'Center Defensive Midfield'}, 'teammate': True}, {'location': [110.0, 30.0], 'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'teammate': True}]                                                                                                                                             1
# [{'location': [112.0, 37.0], 'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [107.0, 65.0], 'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'teammate': True}, {'location': [105.0, 33.0], 'player': {'id': 3336, 'name': 'Harry Maguire'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': True}, {'location': [118.0, 41.0], 'player': {'id': 3509, 'name': 'Thibaut Courtois'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [99.0, 66.0], 'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [111.0, 53.0], 'player': {'id': 3293, 'name': 'Jesse Lingard'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'teammate': True}, {'location': [113.0, 52.0], 'player': {'id': 3089, 'name': 'Kevin De Bruyne'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'teammate': False}, {'location': [112.0, 49.0], 'player': {'id': 2954, 'name': 'Youri Tielemans'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'teammate': False}, {'location': [107.0, 56.0], 'player': {'id': 5642, 'name': 'Axel Witsel'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'teammate': False}, {'location': [111.0, 44.0], 'player': {'id': 6332, 'name': 'Thomas Vermaelen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [111.0, 41.0], 'player': {'id': 3101, 'name': 'Vincent Kompany'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [110.0, 34.0], 'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [108.0, 38.0], 'player': {'id': 3504, 'name': 'Ruben Loftus-Cheek'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': True}]                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# [{'location': [119.0, 40.0], 'player': {'id': 3509, 'name': 'Thibaut Courtois'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [114.0, 33.0], 'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'teammate': True}, {'location': [117.0, 34.0], 'player': {'id': 3318, 'name': 'Marcus Rashford'}, 'position': {'id': 24, 'name': 'Left Center Forward'}, 'teammate': True}, {'location': [116.0, 39.0], 'player': {'id': 3293, 'name': 'Jesse Lingard'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'teammate': True}, {'location': [112.0, 42.0], 'player': {'id': 6332, 'name': 'Thomas Vermaelen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [114.0, 48.0], 'player': {'id': 3089, 'name': 'Kevin De Bruyne'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'teammate': False}, {'location': [109.0, 39.0], 'player': {'id': 3101, 'name': 'Vincent Kompany'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [111.0, 33.0], 'player': {'id': 5642, 'name': 'Axel Witsel'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'teammate': False}, {'location': [116.0, 35.0], 'player': {'id': 2954, 'name': 'Youri Tielemans'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'teammate': False}, {'location': [111.0, 45.0], 'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [117.0, 39.0], 'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [111.0, 41.0], 'player': {'id': 3504, 'name': 'Ruben Loftus-Cheek'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': True}, {'location': [113.0, 44.0], 'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [112.0, 47.0], 'player': {'id': 10956, 'name': 'Eric Dier'}, 'position': {'id': 10, 'name': 'Center Defensive Midfield'}, 'teammate': True}]                                                                                                                                                                                                                                                                           1
# [{'location': [104.0, 45.0], 'player': {'id': 3318, 'name': 'Marcus Rashford'}, 'position': {'id': 24, 'name': 'Left Center Forward'}, 'teammate': True}, {'location': [104.0, 47.0], 'player': {'id': 2954, 'name': 'Youri Tielemans'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'teammate': False}, {'location': [98.0, 55.0], 'player': {'id': 3101, 'name': 'Vincent Kompany'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [100.0, 60.0], 'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [114.0, 49.0], 'player': {'id': 3509, 'name': 'Thibaut Courtois'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [108.0, 44.0], 'player': {'id': 6332, 'name': 'Thomas Vermaelen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [103.0, 42.0], 'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'teammate': True}, {'location': [104.0, 34.0], 'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [104.0, 31.0], 'player': {'id': 4597, 'name': 'Fabian Delph'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': True}, {'location': [111.0, 41.0], 'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# ...
# [{'location': [118.0, 42.0], 'player': {'id': 3509, 'name': 'Thibaut Courtois'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [113.0, 39.0], 'player': {'id': 3233, 'name': 'Raheem Sterling'}, 'position': {'id': 24, 'name': 'Left Center Forward'}, 'teammate': True}, {'location': [110.0, 35.0], 'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [108.0, 47.0], 'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [105.0, 40.0], 'player': {'id': 2954, 'name': 'Youri Tielemans'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'teammate': False}, {'location': [98.0, 19.0], 'player': {'id': 3594, 'name': 'Danny Rose'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': True}, {'location': [89.0, 32.0], 'player': {'id': 4597, 'name': 'Fabian Delph'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'teammate': True}, {'location': [106.0, 58.0], 'player': {'id': 3101, 'name': 'Vincent Kompany'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [99.0, 52.0], 'player': {'id': 5642, 'name': 'Axel Witsel'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'teammate': False}, {'location': [104.0, 64.0], 'player': {'id': 4831, 'name': 'Nacer Chadli'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [106.0, 61.0], 'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'teammate': True}, {'location': [111.0, 41.0], 'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{'location': [118.0, 41.0], 'player': {'id': 3509, 'name': 'Thibaut Courtois'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [100.0, 21.0], 'player': {'id': 3233, 'name': 'Raheem Sterling'}, 'position': {'id': 24, 'name': 'Left Center Forward'}, 'teammate': True}, {'location': [101.0, 24.0], 'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [91.0, 27.0], 'player': {'id': 2954, 'name': 'Youri Tielemans'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'teammate': False}, {'location': [92.0, 34.0], 'player': {'id': 5642, 'name': 'Axel Witsel'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'teammate': False}, {'location': [89.0, 42.0], 'player': {'id': 3504, 'name': 'Ruben Loftus-Cheek'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'teammate': True}, {'location': [99.0, 62.0], 'player': {'id': 4831, 'name': 'Nacer Chadli'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [102.0, 40.0], 'player': {'id': 3101, 'name': 'Vincent Kompany'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [102.0, 46.0], 'player': {'id': 3077, 'name': 'Jan Vertonghen'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [89.0, 16.0], 'player': {'id': 3594, 'name': 'Danny Rose'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': True}, {'location': [101.0, 31.0], 'player': {'id': 20005, 'name': 'Toby Alderweireld'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [102.0, 43.0], 'player': {'id': 10955, 'name': 'Harry Kane'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'teammate': True}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# [{'location': [118.0, 38.0], 'player': {'id': 3468, 'name': 'Jordan Pickford'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [100.0, 54.0], 'player': {'id': 3594, 'name': 'Danny Rose'}, 'position': {'id': 8, 'name': 'Left Wing Back'}, 'teammate': False}, {'location': [98.0, 56.0], 'player': {'id': 3289, 'name': 'Romelu Lukaku Menama'}, 'position': {'id': 23, 'name': 'Center Forward'}, 'teammate': True}, {'location': [93.0, 61.0], 'player': {'id': 3176, 'name': 'Thomas Meunier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': True}, {'location': [107.0, 48.0], 'player': {'id': 3336, 'name': 'Harry Maguire'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [105.0, 44.0], 'player': {'id': 3314, 'name': 'Phil Jones'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [100.0, 48.0], 'player': {'id': 3621, 'name': 'Eden Hazard'}, 'position': {'id': 21, 'name': 'Left Wing'}, 'teammate': True}, {'location': [97.0, 46.0], 'player': {'id': 4597, 'name': 'Fabian Delph'}, 'position': {'id': 15, 'name': 'Left Center Midfield'}, 'teammate': False}, {'location': [108.0, 31.0], 'player': {'id': 3244, 'name': 'John Stones'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [110.0, 30.0], 'player': {'id': 3308, 'name': 'Kieran Trippier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [104.0, 38.0], 'player': {'id': 10956, 'name': 'Eric Dier'}, 'position': {'id': 10, 'name': 'Center Defensive Midfield'}, 'teammate': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{'location': [117.0, 39.0], 'player': {'id': 3468, 'name': 'Jordan Pickford'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'teammate': False}, {'location': [111.0, 33.0], 'player': {'id': 3314, 'name': 'Phil Jones'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [106.0, 22.0], 'player': {'id': 5630, 'name': 'Dries Mertens'}, 'position': {'id': 23, 'name': 'Center Forward'}, 'teammate': True}, {'location': [108.0, 36.0], 'player': {'id': 3244, 'name': 'John Stones'}, 'position': {'id': 4, 'name': 'Center Back'}, 'teammate': False}, {'location': [106.0, 41.0], 'player': {'id': 3336, 'name': 'Harry Maguire'}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'teammate': False}, {'location': [100.0, 34.0], 'player': {'id': 3089, 'name': 'Kevin De Bruyne'}, 'position': {'id': 17, 'name': 'Right Wing'}, 'teammate': True}, {'location': [96.0, 25.0], 'player': {'id': 3308, 'name': 'Kieran Trippier'}, 'position': {'id': 7, 'name': 'Right Wing Back'}, 'teammate': False}, {'location': [94.0, 31.0], 'player': {'id': 10956, 'name': 'Eric Dier'}, 'position': {'id': 10, 'name': 'Center Defensive Midfield'}, 'teammate': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# Name: shot_freeze_frame, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 15.0    8
# 55.0    2
# 52.0    1
# 53.0    1
# Name: goalkeeper_outcome_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Success           8
# No Touch          2
# In Play Danger    1
# In Play Safe      1
# Name: goalkeeper_outcome_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 32.0    17
# 33.0     7
# 25.0     3
# 26.0     2
# Name: goalkeeper_type_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Shot Faced       17
# Shot Saved        7
# Collected         3
# Goal Conceded     2
# Name: goalkeeper_type_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 44.0    23
# 43.0     2
# 42.0     1
# Name: goalkeeper_position_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Set       23
# Prone      2
# Moving     1
# Name: goalkeeper_position_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    8
# Name: pass_backheel, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    4
# Name: dribble_overrun, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    1
# Name: ball_recovery_offensive, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    3
# Name: pass_aerial_won, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    1
# Name: foul_committed_advantage, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    1
# Name: foul_won_advantage, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    22
# Name: pass_shot_assist, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# [2.0, 42.0]    3
# [3.0, 39.0]    3
# [4.0, 40.0]    2
# [2.0, 40.0]    2
# [2.0, 41.0]    2
# [4.0, 39.0]    1
# [3.0, 43.0]    1
# [7.0, 32.0]    1
# [3.0, 40.0]    1
# [3.0, 42.0]    1
# Name: goalkeeper_end_location, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    4
# Name: ball_recovery_recovery_failure, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    1
# Name: shot_deflected, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    2
# Name: block_deflection, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 45.0    4
# 46.0    3
# Name: goalkeeper_technique_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Diving      4
# Standing    3
# Name: goalkeeper_technique_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 35.0    6
# 41.0    1
# Name: goalkeeper_body_part_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Both Hands    6
# Right Hand    1
# Name: goalkeeper_body_part_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    21
# Name: pass_switch, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    2
# Name: shot_aerial_won, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    4
# Name: foul_won_defensive, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    1
# Name: pass_deflected, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    1
# Name: shot_redirect, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 103.0    5
# 102.0    1
# Name: substitution_outcome_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Tactical    5
# Injury      1
# Name: substitution_outcome_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 6332.0    1
# 3293.0    1
# 3318.0    1
# 5630.0    1
# 3037.0    1
# 3094.0    1
# Name: substitution_replacement_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Thomas Vermaelen           1
# Jesse Lingard              1
# Marcus Rashford            1
# Dries Mertens              1
# Mousa Sidi Yaya Dembélé    1
# Bamidele Alli              1
# Name: substitution_replacement_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 7.0    1
# Name: foul_committed_card_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Yellow Card    1
# Name: foul_committed_card_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    1
# Name: pass_cut_back, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    2
# Name: shot_one_on_one, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    1
# Name: block_save_block, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 24.0    1
# Name: foul_committed_type_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Handball    1
# Name: foul_committed_type_name, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# True    1
# Name: foul_committed_offensive, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# 7.0    2
# Name: bad_behaviour_card_id, dtype: int64
# -----------FIM-------------
# -----------INICIO-------------
# Yellow Card    2
# Name: bad_behaviour_card_name, dtype: int64
# -----------FIM-------------
